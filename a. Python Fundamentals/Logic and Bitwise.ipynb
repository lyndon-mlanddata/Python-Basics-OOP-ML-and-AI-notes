# %% [markdown]
# # Comparison Opertors
#
# ### Comparison Operators are used to compare one variable to another
# ==,>=,<=,!=

# %%
2 == 2
# Out:
# True

# %%
2 == 3
# Out:
# False

# %%
2>= 3
# Out:
# False

# %%
3>=2
# Out:
# True

# %%
2<=3
# Out:
# True

# %%
3<=2
# Out:
# False

# %%
2 != 3
# Out:
# True

# %%
2 != 2
# Out:
# False

# %% [markdown]
# # Logic Operators
# ### Compare two values
#
# AND,OR, NOT

# %%
a = 3
b = 2
a == 3 and b ==2
# Out:
# True

# %%
a >1 and b < 4
# Out:
# True

# %%
a ==4 or b ==1
# Out:
# False

# %%
a==2 or b==2
# Out:
# True

# %%
a1 = True 
not a1
# Out:
# False

# %% [markdown]
# ## Bitwise Operators - i dont undertand this bs

# %%
#10 = 1010
#11 = 1011
"""
it returns 1 if both bits are 1
it compares the
bits one by one, for example , 1 and 1 , therefore it returns 1, 0 and 0, it returns 0, 
1 and 1 it returns 1, 0 and 1 and it returns 1" so it returns 1011 , which is 10
"""
10&11
# Out:
# 10

# %%
#OR
10| 12
# Out:
# 14

# %%
12|14
# Out:
# 14

# %%
#NOT
~11
# Out:
# -12

# %%
12<<2
# Out:
# 48

# %%
12>>2
#12 = 1100, ">>" means move 2 two bits to the left, resulting in 1100 going to 0011
# Out:
# 3

# %%
10^12
# it returns 1 
#if one bit is 1 and the other is 0, if both
#bits are 1 or both bit are 0 then it returns 0
# Out:
# 6
