# %% [markdown]
# # Identity and Memebership Operators

# %% [markdown]
# ### "is" operator

# %%
x=10
y=10
x is y
# Out:
# True

# %%
z =12
x is z
# Out:
# False

# %% [markdown]
# ### "is not" operator

# %%
x is not z
# Out:
# True

# %%
x is not y
# Out:
# False

# %% [markdown]
# ## Memebership Operator

# %% [markdown]
# ### "in" operator

# %%
t = [1,2,3,4,5]
3 in t
# Out:
# True

# %%
45 in t
# Out:
# False

# %% [markdown]
# ### "not" operator

# %%
4 not in t
# Out:
# False

# %%
45 not in t
# Out:
# True
