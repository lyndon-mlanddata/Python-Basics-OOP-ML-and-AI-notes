# %% [markdown]
# ## Variables

# %%
a= 85
b=75
c=25

# %%
a
# Out:
# 85

# %%
b
# Out:
# 75

# %%
c
# Out:
# 25

# %%
4% = 5
# Out:
#   Cell In[10], line 1
#     4% = 5
#        ^
# SyntaxError: invalid syntax

# %% [markdown]
# you cannot name a variable after an integer or float or any symbol other than _

# %%
b
# Out:
# 75

# %%
h, i, j , k , l =2, "end",4,"start",4.3

# %%
h
# Out:
# 2

# %%
k
# Out:
# 'start'

# %% [markdown]
# you can name variables like this
