# %% [markdown]
# ## Arithmetic Operators

# %% [markdown]
# ### addition,subtraction, multiplication and division

# %%
a=2 + 3
b=5-2
c=4*8
d=32/4
print(a,b,c,d)
# Out:
# 5 3 32 8.0

# %% [markdown]
# ## modulus operator
# ### returns the remainder of the operation a/b

# %%
3 % 2
#3/2 is 1 remainder 1
# Out:
# 1

# %%
45%7
#45/7 i 6 remainder 3
# Out:
# 3

# %% [markdown]
# ## exponent operator
# ### repeatedly multiplies a by b times in a^b

# %%
3**2
# Out:
# 9

# %%
4**5
# Out:
# 1024

# %% [markdown]
# ##  Assignment operators
# ### = , +=,-=,*=,**=,/=,%=
# ### eg a += b means a  = a + b

# %%
a =3
b=4
a += b
print(a)
# Out:
# 7

# %%
a = 2
b = 3
a-=b
print(a)
# Out:
# -1

# %%
a = 5
b= 7
a*=b
print(a)
# Out:
# 35

# %%
a= 20
b = 30
a/=b
print(a)
# Out:
# 0.6666666666666666

# %%
a = 3
b=8
b **= a
print(b)
# Out:
# 512

# %%
a = 40
b = 3
a %= b
print (a)
# Out:
# 1

# %% [markdown]
# ### floor divider
# ### a//=b means a = a//b
# all it does is divide a by b then gives the INTEGER solution, not decimal or fraction

# %%
a = 20
b = 3
a//=b
print(a)

#this gives  6 instead of 6.6666
# Out:
# 6
