# %% [markdown]
# # Conditional Statements

# %% [markdown]
# ### if, elif and else

# %% [markdown]
# if(condition):
#     statement(s)
# indentation is improtant

# %%
x = 3
if x > 0:
    print("x is greater than 0")
# Out:
# x is greater than 0

# %%
x = 5
if x%2 == 0:
    print("x is divisible by 2")
elif x%2 != 0:
    print("x is not divisible by 2")
# Out:
# x is not divisible by 2

# %%
y = 34
if y<10:
    pritn("y is less than 10")
elif y >10 and y<30:
    print("y is betwen 10 and 30")
else:
    print("y is greater than 30")
# Out:
# y is greater than 30
