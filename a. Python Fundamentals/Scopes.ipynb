# %%
#local scope
def func():
    x =5
    print(x)

# %%
func()
# Out:
# 5

# %%
def func():
    a =5
print(a)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[19], line 3
#       1 def func():
#       2     a =5
# ----> 3 print(a)
#
# NameError: name 'a' is not defined

# %%
#globAL SCOPE
y =10
def myfunc():
    print(y)

# %%
myfunc()
# Out:
# 10

# %%
#ninja trick 
def myfunc2():
    global z 
    z = 13
    print(z)

# %%
myfunc2()
# Out:
# 13
