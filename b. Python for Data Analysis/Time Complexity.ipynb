# %% [markdown]
# # Time Conmplexity

# %% [markdown]
# - the time complexity of an algorithm quantifies the amount of time taken by an algorithm
# - it estimate the time complexity of an algorithm by counting th}e number of operations performed by the algorithm
# - we always assume th eworst case scenario and fix it before releasing it to our customers(in programming at companies and real world etc

# %% [markdown]
# #### Examples

# %%
# 1
if 5>3:
    print('True')
else:
    print('False')

# time complexity = O(1)
# 2
A = [2,4,6,7,9]
# best case scenario - search for 2 from the 0th index
# worst case scenario - search for 9 from the 0th index
