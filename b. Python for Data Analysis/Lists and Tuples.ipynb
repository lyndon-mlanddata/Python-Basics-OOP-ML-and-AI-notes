# %% [markdown]
# # Lists and Tuples
# ### Lists
# A list is a collection of multiple values

# %%
fruits = ["apple", "banana", "cherry"]

# %% [markdown]
# ### Tuples
# A tuple is an immutable (cannot be changed)  sequence of Python objects.

# %%
n = (1,2,3,4,5,6)

# %%
n[2] =33
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 n[2] =33
#
# TypeError: 'tuple' object does not support item assignment

# %%
# the error above is becuase n is a tuple and is immutable
