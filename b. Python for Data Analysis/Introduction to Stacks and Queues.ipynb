# %% [markdown]
# ### Stacks
# Last In First Out(LIFO)
#
# We use two operations to make stacks
#
# - pop
# - push

# %% [markdown]
# ### Queues
# First In First Out(FIFO)
#
# example- in queue for a cimea ticket, the first person is the first one to buy a ticket and the first one to leave
#
# to implemenet queues we use
# - enqueue- adds an element at the end of the queue
# - dequeue- removes elemeents from the beginning of the queue
