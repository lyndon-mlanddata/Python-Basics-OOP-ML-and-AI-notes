# %% [markdown]
# # Bubble Sort
# - iterates through the lsit repeatedly to sort the elements inside of it
# - It does this by swapping elements if they are in the wrong order

# %%
my_list = [3,1,4,7,2]
# first pass swaps 3 and 1 and swaps 7 and 2
# and we a re left with [1,3,4,2,7]
# second pass swaps only 4 and 2 
# and we a re left with [1,3,2,4,7]
# this is done a gain on the third pass untill we finally end up with
# [1,2,3,4,7]

#time complexity is 
"""
i = 1  n times
i = 2  n-1 times
i = 3  n-2 times
...
i = n  1 times
n*(n + (1+2+£+4....)
time complexity = O(n^2)
"""
# Out:
# '\ni = 1  n times\ni = 2  n-1 times\ni = 3  n-2 times\n...\ni = n  1 times\nn*(n + (1+2+£+4....)\ntime complexity = O(n^2)\n'
