# %% [markdown]
# # Encapsulation
# the process of wrapping up variables and methods into a single entity

# %%
class person:
    def __init__(self,name,age):
        self.name = name
        self.age = age
    def display(self):
        print(slef.name,self.age)
    def modify_age(self,new_age):
        self.age = new_age

# %%
p1 = person("Eddy",23)
p1.display()

p1.modify_age(56)
p1.
