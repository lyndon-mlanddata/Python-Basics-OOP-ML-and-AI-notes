# %% [markdown]
# # Analytical Functions
# 1. eval()
# 2. len()
# 3. factorial()
# 4. sort()

# %%
# eval()
x=3
eval("x**2+2*x-2") #  can use it on a string
# Out:
# 13

# %%
# len()
numbers = [4,76,2 ,34,12,9]
len(numbers)
# Out:
# 6

# %%
#  factorial()
import math 
math.factorial(9)
# Out:
# 362880

# %%
# sort()
runs = [45,10,150,76,20,90,200]
runs.sort(reverse
