# %% [markdown]
# # Introduction to Functions
#
# Functions are a group of statements which work togwther to run a specific task and only works when it is called

# %%
def myFunc():
    a=1
    b=4
    c=a+b
    return c;

# %%
myFunc()
# Out:
# 5
